# %% [markdown]
# # Circles Quadratic

# %%
# 导入
import sys

sys.path.append("E:/dataFiles/github/MFlow")

# %%
# 数据生成
from sklearn.datasets import make_circles
from mflow import utils

# 加载同心圆数据
xs, ys = make_circles(200, noise=0.1, factor=0.2)
ys = ys * 2 - 1  # 0/1转换为-1/1

print(xs.shape, ys.shape)
print(xs[0], ys[0])
utils.drawXYDatas(xs, ys)
# Out:
# (200, 2) (200,)
# [0.05689349 0.05511828] 1

# %%
# 训练
import numpy as np
from mflow import core, ops, opts
# from mflow import utils

# 超参数
lr = 0.001
epoch = 200
batch_size = 8

with core.NameScope("Quadratic"):
    # 初始化变量
    x = core.Variable(size=(2, 1), trainable=False)
    y = core.Variable(size=(1, 1), trainable=False)
    w2 = core.Variable(size=(2, 2), trainable=True)
    w1 = core.Variable(size=(1, 2), trainable=True)
    b = core.Variable(size=(1, 1), trainable=True)
    # 模型定义
    pred = ops.Add(
        ops.MatMul(ops.Reshape(x, shape=(1, 2)), ops.MatMul(w2, x)),  # 二次项
        ops.MatMul(w1, x),  # 一次项
        b  # 偏置项
    )
    predicter = ops.Logistic(pred)
    loss = ops.loss.LogLoss(ops.Multiply(y, pred))
    adam = opts.Adam(core.DefaultGraph, loss, lr)
    # utils.drawGraph(core.DefaultGraph)
    # 开始训练
    for ep in range(1, epoch + 1):
        bs_idx = 0  # 批次计数
        # 这是一个epoch的过程
        for i, (feat, lab) in enumerate(zip(xs, ys)):
            x.setValue(np.mat(feat).T)
            y.setValue(np.mat(lab))
            adam.step()
            bs_idx += 1
            if bs_idx == batch_size:
                adam.update()
                bs_idx = 0
        # 一个epoch完成后进行评估
        preds = []
        for feat in xs:
            x.setValue(np.mat(feat).T)
            predicter.forward()
            preds.append(predicter.value[0, 0])  # 结果
        preds = (np.array(preds) > 0.5).astype("int") * 2 - 1
        acc = (ys == preds).astype("uint8").sum() / len(xs)
        print("Epoch: {:d}, acc: {:.3f}.".format(ep, acc))
    # 查看权重
    print("w2:\n", w2.value)
    print("w1:\n", w1.value)
    print("b:\n", b.value)
# Out:
# Epoch: 1, acc: 0.500.
# Epoch: 2, acc: 0.545.
# Epoch: 3, acc: 0.635.
# Epoch: 4, acc: 0.735.
# Epoch: 5, acc: 0.820.
# Epoch: 6, acc: 0.880.
# Epoch: 7, acc: 0.925.
# Epoch: 8, acc: 0.950.
# Epoch: 9, acc: 0.955.
# Epoch: 10, acc: 0.960.
# Epoch: 11, acc: 0.980.
# Epoch: 12, acc: 0.985.
# Epoch: 13, acc: 0.985.
# Epoch: 14, acc: 0.990.
# Epoch: 15, acc: 0.995.
# Epoch: 16, acc: 0.995.
# Epoch: 17, acc: 0.995.
# Epoch: 18, acc: 0.995.
# Epoch: 19, acc: 0.995.
# Epoch: 20, acc: 0.995.
# Epoch: 21, acc: 0.995.
# Epoch: 22, acc: 0.995.
# Epoch: 23, acc: 0.995.
# Epoch: 24, acc: 0.995.
# Epoch: 25, acc: 1.000.
# Epoch: 26, acc: 1.000.
# Epoch: 27, acc: 1.000.
# Epoch: 28, acc: 1.000.
# Epoch: 29, acc: 1.000.
# Epoch: 30, acc: 1.000.
# Epoch: 31, acc: 1.000.
# Epoch: 32, acc: 1.000.
# Epoch: 33, acc: 1.000.
# Epoch: 34, acc: 1.000.
# Epoch: 35, acc: 1.000.
# Epoch: 36, acc: 1.000.
# Epoch: 37, acc: 1.000.
# Epoch: 38, acc: 1.000.
# Epoch: 39, acc: 1.000.
# Epoch: 40, acc: 1.000.
# Epoch: 41, acc: 1.000.
# Epoch: 42, acc: 1.000.
# Epoch: 43, acc: 1.000.
# Epoch: 44, acc: 1.000.
# Epoch: 45, acc: 1.000.
# Epoch: 46, acc: 1.000.
# Epoch: 47, acc: 1.000.
# Epoch: 48, acc: 1.000.
# Epoch: 49, acc: 1.000.
# Epoch: 50, acc: 1.000.
# Epoch: 51, acc: 1.000.
# Epoch: 52, acc: 1.000.
# Epoch: 53, acc: 1.000.
# Epoch: 54, acc: 1.000.
# Epoch: 55, acc: 1.000.
# Epoch: 56, acc: 1.000.
# Epoch: 57, acc: 1.000.
# Epoch: 58, acc: 1.000.
# Epoch: 59, acc: 1.000.
# Epoch: 60, acc: 1.000.
# Epoch: 61, acc: 1.000.
# Epoch: 62, acc: 1.000.
# Epoch: 63, acc: 1.000.
# Epoch: 64, acc: 1.000.
# Epoch: 65, acc: 1.000.
# Epoch: 66, acc: 1.000.
# Epoch: 67, acc: 1.000.
# Epoch: 68, acc: 1.000.
# Epoch: 69, acc: 1.000.
# Epoch: 70, acc: 1.000.
# Epoch: 71, acc: 1.000.
# Epoch: 72, acc: 1.000.
# Epoch: 73, acc: 1.000.
# Epoch: 74, acc: 1.000.
# Epoch: 75, acc: 1.000.
# Epoch: 76, acc: 1.000.
# Epoch: 77, acc: 1.000.
# Epoch: 78, acc: 1.000.
# Epoch: 79, acc: 1.000.
# Epoch: 80, acc: 1.000.
# Epoch: 81, acc: 1.000.
# Epoch: 82, acc: 1.000.
# Epoch: 83, acc: 1.000.
# Epoch: 84, acc: 1.000.
# Epoch: 85, acc: 1.000.
# Epoch: 86, acc: 1.000.
# Epoch: 87, acc: 1.000.
# Epoch: 88, acc: 1.000.
# Epoch: 89, acc: 1.000.
# Epoch: 90, acc: 1.000.
# Epoch: 91, acc: 1.000.
# Epoch: 92, acc: 1.000.
# Epoch: 93, acc: 1.000.
# Epoch: 94, acc: 1.000.
# Epoch: 95, acc: 1.000.
# Epoch: 96, acc: 1.000.
# Epoch: 97, acc: 1.000.
# Epoch: 98, acc: 1.000.
# Epoch: 99, acc: 1.000.
# Epoch: 100, acc: 1.000.
# Epoch: 101, acc: 1.000.
# Epoch: 102, acc: 1.000.
# Epoch: 103, acc: 1.000.
# Epoch: 104, acc: 1.000.
# Epoch: 105, acc: 1.000.
# Epoch: 106, acc: 1.000.
# Epoch: 107, acc: 1.000.
# Epoch: 108, acc: 1.000.
# Epoch: 109, acc: 1.000.
# Epoch: 110, acc: 1.000.
# Epoch: 111, acc: 1.000.
# Epoch: 112, acc: 1.000.
# Epoch: 113, acc: 1.000.
# Epoch: 114, acc: 1.000.
# Epoch: 115, acc: 1.000.
# Epoch: 116, acc: 1.000.
# Epoch: 117, acc: 1.000.
# Epoch: 118, acc: 1.000.
# Epoch: 119, acc: 1.000.
# Epoch: 120, acc: 1.000.
# Epoch: 121, acc: 1.000.
# Epoch: 122, acc: 1.000.
# Epoch: 123, acc: 1.000.
# Epoch: 124, acc: 1.000.
# Epoch: 125, acc: 1.000.
# Epoch: 126, acc: 1.000.
# Epoch: 127, acc: 1.000.
# Epoch: 128, acc: 1.000.
# Epoch: 129, acc: 1.000.
# Epoch: 130, acc: 1.000.
# Epoch: 131, acc: 1.000.
# Epoch: 132, acc: 1.000.
# Epoch: 133, acc: 1.000.
# Epoch: 134, acc: 1.000.
# Epoch: 135, acc: 1.000.
# Epoch: 136, acc: 1.000.
# Epoch: 137, acc: 1.000.
# Epoch: 138, acc: 1.000.
# Epoch: 139, acc: 1.000.
# Epoch: 140, acc: 1.000.
# Epoch: 141, acc: 1.000.
# Epoch: 142, acc: 1.000.
# Epoch: 143, acc: 1.000.
# Epoch: 144, acc: 1.000.
# Epoch: 145, acc: 1.000.
# Epoch: 146, acc: 1.000.
# Epoch: 147, acc: 1.000.
# Epoch: 148, acc: 1.000.
# Epoch: 149, acc: 1.000.
# Epoch: 150, acc: 1.000.
# Epoch: 151, acc: 1.000.
# Epoch: 152, acc: 1.000.
# Epoch: 153, acc: 1.000.
# Epoch: 154, acc: 1.000.
# Epoch: 155, acc: 1.000.
# Epoch: 156, acc: 1.000.
# Epoch: 157, acc: 1.000.
# Epoch: 158, acc: 1.000.
# Epoch: 159, acc: 1.000.
# Epoch: 160, acc: 1.000.
# Epoch: 161, acc: 1.000.
# Epoch: 162, acc: 1.000.
# Epoch: 163, acc: 1.000.
# Epoch: 164, acc: 1.000.
# Epoch: 165, acc: 1.000.
# Epoch: 166, acc: 1.000.
# Epoch: 167, acc: 1.000.
# Epoch: 168, acc: 1.000.
# Epoch: 169, acc: 1.000.
# Epoch: 170, acc: 1.000.
# Epoch: 171, acc: 1.000.
# Epoch: 172, acc: 1.000.
# Epoch: 173, acc: 1.000.
# Epoch: 174, acc: 1.000.
# Epoch: 175, acc: 1.000.
# Epoch: 176, acc: 1.000.
# Epoch: 177, acc: 1.000.
# Epoch: 178, acc: 1.000.
# Epoch: 179, acc: 1.000.
# Epoch: 180, acc: 1.000.
# Epoch: 181, acc: 1.000.
# Epoch: 182, acc: 1.000.
# Epoch: 183, acc: 1.000.
# Epoch: 184, acc: 1.000.
# Epoch: 185, acc: 1.000.
# Epoch: 186, acc: 1.000.
# Epoch: 187, acc: 1.000.
# Epoch: 188, acc: 1.000.
# Epoch: 189, acc: 1.000.
# Epoch: 190, acc: 1.000.
# Epoch: 191, acc: 1.000.
# Epoch: 192, acc: 1.000.
# Epoch: 193, acc: 1.000.
# Epoch: 194, acc: 1.000.
# Epoch: 195, acc: 1.000.
# Epoch: 196, acc: 1.000.
# Epoch: 197, acc: 1.000.
# Epoch: 198, acc: 1.000.
# Epoch: 199, acc: 1.000.
# Epoch: 200, acc: 1.000.
# w2:
#  [[-4.45378994 -0.1585172 ]
#  [-0.15917692 -4.31438289]]
# w1:
#  [[-0.07815182 -0.0182309 ]]
# b:
#  [[2.10027222]]
